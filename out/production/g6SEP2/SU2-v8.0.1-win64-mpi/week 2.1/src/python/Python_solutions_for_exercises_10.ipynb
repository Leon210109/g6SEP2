# %%
from sympy import *
from IPython.display import Latex, display
init_printing()

# %%
A = Matrix([[1,2,3],[4,5,6],[7,8,9]])
B = Matrix([[9,8,7],[6,5,4],[3,2,1]])

# Solve: X-A=6(X+B)
# X - A = 6X + 6B
# -A - 6B = 5X
# X = -1/5(A + 6B)

X = -1/5*(A + 6*B)
display(X)
